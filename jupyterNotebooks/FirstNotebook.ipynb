# %%
import pandas as pd

# %%
lst = ["cat" , "rat" , "cycle"]
s1 = pd.Series(lst)

# %%
s1
# Out:
# 0      cat
# 1      rat
# 2    cycle
# dtype: object

# %%
s2 = pd.DataFrame(lst)

# %%
s2
# Out:
#        0
# 0    cat
# 1    rat
# 2  cycle

# %%
type(s2)
# Out:
# pandas.core.frame.DataFrame

# %%
s2
# Out:
#        0
# 0    cat
# 1    rat
# 2  cycle

# %%
newlst = {"country":["Brazil" , "India" , "Russia" , "America",],
          "population":[10002,100002,3000,6000],
          "country-code":[101,91,192,90]}
s2 = pd.DataFrame(newlst)
s2
# Out:
#    country  population  country-code
# 0   Brazil       10002           101
# 1    India      100002            91
# 2   Russia        3000           192
# 3  America        6000            90

# %%
s2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       4 non-null      object
#  1   population    4 non-null      int64
#  2   country-code  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
s2.head()
# Out:
#    country  population  country-code
# 0   Brazil       10002           101
# 1    India      100002            91
# 2   Russia        3000           192
# 3  America        6000            90

# %%
s1 = pd.read_csv("bezdekIris.data")

# %%
s1
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
s2
# Out:
#    country  population  country-code
# 0   Brazil       10002           101
# 1    India      100002            91
# 2   Russia        3000           192
# 3  America        6000            90

# %%
s2 = pd.read_csv("bezdekIris.data")

# %%
s2
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
s2.describe()
# Out:
#               5.1         3.5         1.4         0.2
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.054362    3.773826    1.206040
# std      0.828594    0.435810    1.760543    0.760354
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
s2[["5.1"]].describe()
# Out:
#               5.1
# count  149.000000
# mean     5.848322
# std      0.828594
# min      4.300000
# 25%      5.100000
# 50%      5.800000
# 75%      6.400000
# max      7.900000

# %%
s2[["5.1"]].value_counts()
# Out:
# 5.1
# 5.0    10
# 6.3     9
# 5.7     8
# 6.7     8
# 5.1     8
# 6.4     7
# 5.8     7
# 5.5     7
# 5.4     6
# 6.1     6
# 5.6     6
# 6.0     6
# 4.9     6
# 4.8     5
# 6.5     5
# 6.2     4
# 5.2     4
# 4.6     4
# 7.7     4
# 6.9     4
# 7.2     3
# 5.9     3
# 4.4     3
# 6.8     3
# 4.7     2
# 6.6     2
# 7.4     1
# 7.6     1
# 7.3     1
# 4.3     1
# 7.1     1
# 7.0     1
# 5.3     1
# 4.5     1
# 7.9     1
# dtype: int64

# %%
s2[["5.1"]].value_counts(normalize=True )
# Out:
# 5.1
# 5.0    0.067114
# 6.3    0.060403
# 5.7    0.053691
# 6.7    0.053691
# 5.1    0.053691
# 6.4    0.046980
# 5.8    0.046980
# 5.5    0.046980
# 5.4    0.040268
# 6.1    0.040268
# 5.6    0.040268
# 6.0    0.040268
# 4.9    0.040268
# 4.8    0.033557
# 6.5    0.033557
# 6.2    0.026846
# 5.2    0.026846
# 4.6    0.026846
# 7.7    0.026846
# 6.9    0.026846
# 7.2    0.020134
# 5.9    0.020134
# 4.4    0.020134
# 6.8    0.020134
# 4.7    0.013423
# 6.6    0.013423
# 7.4    0.006711
# 7.6    0.006711
# 7.3    0.006711
# 4.3    0.006711
# 7.1    0.006711
# 7.0    0.006711
# 5.3    0.006711
# 4.5    0.006711
# 7.9    0.006711
# dtype: float64

# %%
s1 = pd.read_csv("bezdekIris.data")

# %%
s1
# Out:
#      Data1  Data2  Data3  Data4  Classification
# 0      5.1    3.5    1.4    0.2     Iris-setosa
# 1      4.9    3.0    1.4    0.2     Iris-setosa
# 2      4.7    3.2    1.3    0.2     Iris-setosa
# 3      4.6    3.1    1.5    0.2     Iris-setosa
# 4      5.0    3.6    1.4    0.2     Iris-setosa
# ..     ...    ...    ...    ...             ...
# 145    6.7    3.0    5.2    2.3  Iris-virginica
# 146    6.3    2.5    5.0    1.9  Iris-virginica
# 147    6.5    3.0    5.2    2.0  Iris-virginica
# 148    6.2    3.4    5.4    2.3  Iris-virginica
# 149    5.9    3.0    5.1    1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
s1.value_counts()
# Out:
# Data1  Data2  Data3  Data4  Classification
# 5.8    2.7    5.1    1.9    Iris-virginica     2
# 6.2    2.2    4.5    1.5    Iris-versicolor    1
#        2.9    4.3    1.3    Iris-versicolor    1
#        3.4    5.4    2.3    Iris-virginica     1
# 6.3    2.3    4.4    1.3    Iris-versicolor    1
#                                               ..
# 5.4    3.9    1.3    0.4    Iris-setosa        1
#               1.7    0.4    Iris-setosa        1
# 5.5    2.3    4.0    1.3    Iris-versicolor    1
#        2.4    3.7    1.0    Iris-versicolor    1
# 7.9    3.8    6.4    2.0    Iris-virginica     1
# Length: 149, dtype: int64

# %%
s1
# Out:
#      Data1  Data2  Data3  Data4  Classification
# 0      5.1    3.5    1.4    0.2     Iris-setosa
# 1      4.9    3.0    1.4    0.2     Iris-setosa
# 2      4.7    3.2    1.3    0.2     Iris-setosa
# 3      4.6    3.1    1.5    0.2     Iris-setosa
# 4      5.0    3.6    1.4    0.2     Iris-setosa
# ..     ...    ...    ...    ...             ...
# 145    6.7    3.0    5.2    2.3  Iris-virginica
# 146    6.3    2.5    5.0    1.9  Iris-virginica
# 147    6.5    3.0    5.2    2.0  Iris-virginica
# 148    6.2    3.4    5.4    2.3  Iris-virginica
# 149    5.9    3.0    5.1    1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
s1[["Classification"]].value_counts()
# Out:
# Classification
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.frame.DataFrame

# %%
import matplotlib as plt
plt.__version__
# Out:
# '3.5.1'

# %%
import pandas as pd
# %matplotlib inline
s1 = pd.read_csv("sample.data")

# %%
s1
# Out:
#      Data1  Data2  Data3  Data4  Classification
# 0      5.1    3.5    1.4    0.2     Iris-setosa
# 1      4.9    3.0    1.4    0.2     Iris-setosa
# 2      4.7    3.2    1.3    0.2     Iris-setosa
# 3      4.6    3.1    1.5    0.2     Iris-setosa
# 4      5.0    3.6    1.4    0.2     Iris-setosa
# ..     ...    ...    ...    ...             ...
# 145    6.7    3.0    5.2    2.3  Iris-virginica
# 146    6.3    2.5    5.0    1.9  Iris-virginica
# 147    6.5    3.0    5.2    2.0  Iris-virginica
# 148    6.2    3.4    5.4    2.3  Iris-virginica
# 149    5.9    3.0    5.1    1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
s1.plot(kind = "scatter" , x = "Data1" , y = "Data4")
# Out:
# <AxesSubplot:xlabel='Data1', ylabel='Data4'>

# %%
import pandas as pd
# %matplotlib inline
s1 = pd.read_csv("sample.data")
s1[["Data1"]].plot(kind = "hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
s1.pivot(columns = "Data1" , values = "Data2").plot(kind = "box" , figsize = (10,6) )
# Out:
# <AxesSubplot:>

# %%
s1.groupby("Data1")["Data2"].value_counts().unstack().plot(kind = "bar" , stacked = True , figsize = (10,6))
# Out:
# <AxesSubplot:xlabel='Data1'>

# %%
import pandas as pd
# %matplotlib inline
s1 = pd.read_csv("sample.data")
s1.dropna()
# Out:
#      Data1  Data2  Data3  Data4  Classification
# 0      5.1    3.5    1.4    0.2     Iris-setosa
# 1      4.9    3.0    1.4    0.2     Iris-setosa
# 2      4.7    3.2    1.3    0.2     Iris-setosa
# 3      4.6    3.1    1.5    0.2     Iris-setosa
# 4      5.0    3.6    1.4    0.2     Iris-setosa
# ..     ...    ...    ...    ...             ...
# 145    6.7    3.0    5.2    2.3  Iris-virginica
# 146    6.3    2.5    5.0    1.9  Iris-virginica
# 147    6.5    3.0    5.2    2.0  Iris-virginica
# 148    6.2    3.4    5.4    2.3  Iris-virginica
# 149    5.9    3.0    5.1    1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
s1 = pd.read_csv("sample.data")
s1.dropna()
# Out:
#      Data1  Data2  Data3 Data4  Classification
# 0      5.1    3.5    1.4   na      Iris-setosa
# 1      4.9    3.0    1.4   0.2     Iris-setosa
# 2      4.7    3.2    1.3   0.2     Iris-setosa
# 3      4.6    3.1    1.5   0.2     Iris-setosa
# 4      5.0    3.6    1.4   0.2     Iris-setosa
# ..     ...    ...    ...   ...             ...
# 145    6.7    3.0    5.2   2.3  Iris-virginica
# 146    6.3    2.5    5.0   1.9  Iris-virginica
# 147    6.5    3.0    5.2   2.0  Iris-virginica
# 148    6.2    3.4    5.4   2.3  Iris-virginica
# 149    5.9    3.0    5.1   1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
s1 = pd.read_csv("sample.data")
s1
# Out:
#      Data1  Data2  Data3 Data4  Classification
# 0      5.1    3.5    1.4           Iris-setosa
# 1      4.9    3.0    1.4   0.2     Iris-setosa
# 2      4.7    3.2    1.3   0.2     Iris-setosa
# 3      4.6    3.1    1.5   0.2     Iris-setosa
# 4      5.0    3.6    1.4   0.2     Iris-setosa
# ..     ...    ...    ...   ...             ...
# 145    6.7    3.0    5.2   2.3  Iris-virginica
# 146    6.3    2.5    5.0   1.9  Iris-virginica
# 147    6.5    3.0    5.2   2.0  Iris-virginica
# 148    6.2    3.4    5.4   2.3  Iris-virginica
# 149    5.9    3.0    5.1   1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
s1.fillna({"Data4":1})
# Out:
#      Data1  Data2  Data3 Data4  Classification
# 0      5.1    3.5    1.4           Iris-setosa
# 1      4.9    3.0    1.4   0.2     Iris-setosa
# 2      4.7    3.2    1.3   0.2     Iris-setosa
# 3      4.6    3.1    1.5   0.2     Iris-setosa
# 4      5.0    3.6    1.4   0.2     Iris-setosa
# ..     ...    ...    ...   ...             ...
# 145    6.7    3.0    5.2   2.3  Iris-virginica
# 146    6.3    2.5    5.0   1.9  Iris-virginica
# 147    6.5    3.0    5.2   2.0  Iris-virginica
# 148    6.2    3.4    5.4   2.3  Iris-virginica
# 149    5.9    3.0    5.1   1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
s1 = pd.read_csv("sample.data")
s1
# Out:
#      Data1  Data2  Data3  Data4  Classification
# 0      5.1    3.5    1.4   NaN      Iris-setosa
# 1      4.9    3.0    1.4    0.2     Iris-setosa
# 2      4.7    3.2    1.3    0.2     Iris-setosa
# 3      4.6    3.1    1.5    0.2     Iris-setosa
# 4      5.0    3.6    1.4    0.2     Iris-setosa
# ..     ...    ...    ...    ...             ...
# 145    6.7    3.0    5.2    2.3  Iris-virginica
# 146    6.3    2.5    5.0    1.9  Iris-virginica
# 147    6.5    3.0    5.2    2.0  Iris-virginica
# 148    6.2    3.4    5.4    2.3  Iris-virginica
# 149    5.9    3.0    5.1    1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
s1.dropna()
# Out:
#      Data1  Data2  Data3  Data4  Classification
# 0      5.1    3.5    1.4   NaN      Iris-setosa
# 1      4.9    3.0    1.4    0.2     Iris-setosa
# 2      4.7    3.2    1.3    0.2     Iris-setosa
# 3      4.6    3.1    1.5    0.2     Iris-setosa
# 4      5.0    3.6    1.4    0.2     Iris-setosa
# ..     ...    ...    ...    ...             ...
# 145    6.7    3.0    5.2    2.3  Iris-virginica
# 146    6.3    2.5    5.0    1.9  Iris-virginica
# 147    6.5    3.0    5.2    2.0  Iris-virginica
# 148    6.2    3.4    5.4    2.3  Iris-virginica
# 149    5.9    3.0    5.1    1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
s1.fillna({"Data4":1})
# Out:
#      Data1  Data2  Data3  Data4  Classification
# 0      5.1    3.5    1.4   NaN      Iris-setosa
# 1      4.9    3.0    1.4    0.2     Iris-setosa
# 2      4.7    3.2    1.3    0.2     Iris-setosa
# 3      4.6    3.1    1.5    0.2     Iris-setosa
# 4      5.0    3.6    1.4    0.2     Iris-setosa
# ..     ...    ...    ...    ...             ...
# 145    6.7    3.0    5.2    2.3  Iris-virginica
# 146    6.3    2.5    5.0    1.9  Iris-virginica
# 147    6.5    3.0    5.2    2.0  Iris-virginica
# 148    6.2    3.4    5.4    2.3  Iris-virginica
# 149    5.9    3.0    5.1    1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
s1["Data4"][0] = 1.4
# Out:
# C:\Users\KARTA\AppData\Local\Temp/ipykernel_7432/122660891.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s1["Data4"][0] = 1.4

# %%
s1
# Out:
#      Data1  Data2  Data3 Data4  Classification
# 0      5.1    3.5    1.4   1.4     Iris-setosa
# 1      4.9    3.0    1.4   0.2     Iris-setosa
# 2      4.7    3.2    1.3   0.2     Iris-setosa
# 3      4.6    3.1    1.5   0.2     Iris-setosa
# 4      5.0    3.6    1.4   0.2     Iris-setosa
# ..     ...    ...    ...   ...             ...
# 145    6.7    3.0    5.2   2.3  Iris-virginica
# 146    6.3    2.5    5.0   1.9  Iris-virginica
# 147    6.5    3.0    5.2   2.0  Iris-virginica
# 148    6.2    3.4    5.4   2.3  Iris-virginica
# 149    5.9    3.0    5.1   1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
mask = (s1["Data1"] < 5)
mask
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: Data1, Length: 150, dtype: bool

# %%
s1.loc[mask , "Data4"] = 1

# %%
s1
# Out:
#      Data1  Data2  Data3 Data4  Classification
# 0      5.1    3.5    1.4   1.4     Iris-setosa
# 1      4.9    3.0    1.4     1     Iris-setosa
# 2      4.7    3.2    1.3     1     Iris-setosa
# 3      4.6    3.1    1.5     1     Iris-setosa
# 4      5.0    3.6    1.4   0.2     Iris-setosa
# ..     ...    ...    ...   ...             ...
# 145    6.7    3.0    5.2   2.3  Iris-virginica
# 146    6.3    2.5    5.0   1.9  Iris-virginica
# 147    6.5    3.0    5.2   2.0  Iris-virginica
# 148    6.2    3.4    5.4   2.3  Iris-virginica
# 149    5.9    3.0    5.1   1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
s1
# Out:
#      Data1  Data2  Data3 Data4  Classification
# 0      5.1    3.5    1.4   1.4     Iris-setosa
# 1      4.9    3.0    1.4     1     Iris-setosa
# 2      4.7    3.2    1.3     1     Iris-setosa
# 3      4.6    3.1    1.5     1     Iris-setosa
# 4      5.0    3.6    1.4   0.2     Iris-setosa
# ..     ...    ...    ...   ...             ...
# 145    6.7    3.0    5.2   2.3  Iris-virginica
# 146    6.3    2.5    5.0   1.9  Iris-virginica
# 147    6.5    3.0    5.2   2.0  Iris-virginica
# 148    6.2    3.4    5.4   2.3  Iris-virginica
# 149    5.9    3.0    5.1   1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
s2 = pd.read_csv("sample.data")

# %%
s2 , s1
# Out:
# (     Data1  Data2  Data3  Data4  Classification
#  0      5.1    3.5    1.4   NaN      Iris-setosa
#  1      4.9    3.0    1.4    0.2     Iris-setosa
#  2      4.7    3.2    1.3    0.2     Iris-setosa
#  3      4.6    3.1    1.5    0.2     Iris-setosa
#  4      5.0    3.6    1.4    0.2     Iris-setosa
#  ..     ...    ...    ...    ...             ...
#  145    6.7    3.0    5.2    2.3  Iris-virginica
#  146    6.3    2.5    5.0    1.9  Iris-virginica
#  147    6.5    3.0    5.2    2.0  Iris-virginica
#  148    6.2    3.4    5.4    2.3  Iris-virginica
#  149    5.9    3.0    5.1    1.8  Iris-virginica
#
#  [150 rows x 5 columns],
#       Data1  Data2  Data3 Data4  Classification
#  0      5.1    3.5    1.4   1.4     Iris-setosa
#  1      4.9    3.0    1.4     1     Iris-setosa
#  2      4.7    3.2    1.3     1     Iris-setosa
#  3      4.6    3.1    1.5     1     Iris-setosa
#  4      5.0    3.6    1.4   0.2     Iris-setosa
#  ..     ...    ...    ...   ...             ...
# ...

# %%
mask2 = (s2["Data4"][0] == " NaN ")
mask2
# Out:
# True

# %%
s1 = pd.read_csv("Sample.data")

# %%
s1
# Out:
#      Data1  Data2  Data3  Data4  Classification
# 0      5.1    3.5    1.4    NaN     Iris-setosa
# 1      4.9    3.0    1.4    0.2     Iris-setosa
# 2      4.7    3.2    1.3    0.2     Iris-setosa
# 3      4.6    3.1    1.5    0.2     Iris-setosa
# 4      5.0    3.6    1.4    0.2     Iris-setosa
# ..     ...    ...    ...    ...             ...
# 145    6.7    3.0    5.2    2.3  Iris-virginica
# 146    6.3    2.5    5.0    1.9  Iris-virginica
# 147    6.5    3.0    5.2    2.0  Iris-virginica
# 148    6.2    3.4    5.4    2.3  Iris-virginica
# 149    5.9    3.0    5.1    1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
s1.dropna()
# Out:
#      Data1  Data2  Data3  Data4  Classification
# 1      4.9    3.0    1.4    0.2     Iris-setosa
# 2      4.7    3.2    1.3    0.2     Iris-setosa
# 3      4.6    3.1    1.5    0.2     Iris-setosa
# 4      5.0    3.6    1.4    0.2     Iris-setosa
# 5      5.4    3.9    1.7    0.4     Iris-setosa
# ..     ...    ...    ...    ...             ...
# 145    6.7    3.0    5.2    2.3  Iris-virginica
# 146    6.3    2.5    5.0    1.9  Iris-virginica
# 147    6.5    3.0    5.2    2.0  Iris-virginica
# 148    6.2    3.4    5.4    2.3  Iris-virginica
# 149    5.9    3.0    5.1    1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
s1.fillna({"Data4":1})
s1["Data4"].mean()
# Out:
# 1.2060402684563762

# %%
import pandas as pd
s1 = pd.read_excel("students.xlsx")
s1
# Out:
#       ID  FirstName    LastName                Major              Minor   Age  \
# 0   1869       Hana      Barton              Finance                NaN  22.0
# 1   2010     Alicia      Kanuri           Management                NaN  21.0
# 2   2075      Becca     Swanson            Marketing                NaN  22.0
# 3   2228     Halima       Aminu   Business Analytics                NaN  20.0
# 4   2442      Holly    Robinson              Finance                NaN  20.0
# 5   2858      Carla     Harding          Accountancy                NaN   NaN
# 6   3459       Alex     Swanson          Accountancy                NaN   NaN
# 7   3585     Aminah       Zalim            Marketing                NaN  20.0
# 8   5170        Gus  Cunningham              Finance         Innovation  21.0
# 9   5317     Rafael       Solis   Business Analytics               ACMS   NaN
# 10  5336      Homer       White              Finance                NaN   NaN
# ...

# %%
s1[['Age']].value_counts(normalize = True)
# Out:
# Age
# 20.0    0.285714
# 21.0    0.285714
# 22.0    0.214286
# 18.0    0.142857
# 19.0    0.071429
# dtype: float64

# %%
s1["Age"].plot(kind = "bar" , figsize =(10,6))

# %%
from sklearn.preprocessing import MinMaxScaler
age = MinMaxScaler().fit_transform(s1[["Age"]])
age
# Out:
# array([[1.  ],
#        [0.75],
#        [1.  ],
#        [0.5 ],
#        [0.5 ],
#        [ nan],
#        [ nan],
#        [0.5 ],
#        [0.75],
#        [ nan],
#        [ nan],
#        [ nan],
#        [0.25],
#        [0.  ],
#        [1.  ],
#        [0.5 ],
#        [0.75],
#        [0.  ],
#        [0.75],
#        [ nan]])

# %%
age = pd.DataFrame(age, columns = ["Age"])
age.plot(kind = "hist" )
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
mask = (s1["Age"] == "NaN")
mask
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Age, dtype: bool

# %%
s1 = pd.read_csv("vehicles.csv")
s1
# Out:
#        citympg  cylinders  displacement             drive  highwaympg  \
# 0         14.0          6           4.1     2-Wheel Drive        19.0
# 1         14.0          8           5.0     2-Wheel Drive        20.0
# 2         18.0          8           5.7     2-Wheel Drive        26.0
# 3         21.0          6           4.3  Rear-Wheel Drive        31.0
# 4         14.0          8           4.1  Rear-Wheel Drive        19.0
# ...        ...        ...           ...               ...         ...
# 36974     17.0          8           4.7  Rear-Wheel Drive        25.0
# 36975     16.0          8           6.2  Rear-Wheel Drive        25.0
# 36976     15.0          8           6.2  Rear-Wheel Drive        22.0
# 36977     12.0         12           6.5  Rear-Wheel Drive        16.0
# 36978     13.0         12           6.0  Rear-Wheel Drive        22.0
#
#                 make                    model        class  year  \
# ...

# %%
res = "co2emissions"
y = s1[[res]]

# %%
predictor = list(s1.columns)
predictor
# Out:
# ['citympg',
#  'cylinders',
#  'displacement',
#  'drive',
#  'highwaympg',
#  'make',
#  'model',
#  'class',
#  'year',
#  'transmissiontype',
#  'transmissionspeeds',
#  'co2emissions']

# %%
predictor
# Out:
# ['citympg',
#  'cylinders',
#  'displacement',
#  'drive',
#  'highwaympg',
#  'make',
#  'model',
#  'class',
#  'year',
#  'transmissiontype',
#  'transmissionspeeds']

# %%
x = s1[predictor]
x.head()
# Out:
#    citympg  cylinders  displacement             drive  highwaympg      make  \
# 0     14.0          6           4.1     2-Wheel Drive        19.0     Buick
# 1     14.0          8           5.0     2-Wheel Drive        20.0     Buick
# 2     18.0          8           5.7     2-Wheel Drive        26.0     Buick
# 3     21.0          6           4.3  Rear-Wheel Drive        31.0  Cadillac
# 4     14.0          8           4.1  Rear-Wheel Drive        19.0  Cadillac
#
#                      model       class  year transmissiontype  \
# 0      Electra/Park Avenue  Large Cars  1984        Automatic
# 1      Electra/Park Avenue  Large Cars  1984        Automatic
# 2      Electra/Park Avenue  Large Cars  1984        Automatic
# 3  Fleetwood/DeVille (FWD)  Large Cars  1984        Automatic
# 4   Brougham/DeVille (RWD)  Large Cars  1984        Automatic
#
#    transmissionspeeds
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# ...

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y)

# %%
x_train.shape , y_train.shape , x_test.shape , y_train.shape
# Out:
# ((27734, 11), (27734, 1), (9245, 11), (27734, 1))

# %%
(x["drive"].value_counts(normalize = True) , x_test["drive"].value_counts(normalize = True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13044/881329737.py in <module>
# ----> 1 print(x["drive"].value_counts(normalize = True) , x_test["drive"].value_counts(normalize = True))
#
# NameError: name 'x' is not defined

# %%
import pandas as pd
s1 = pd.read_csv("vehicles.csv")
res = "co2emissions"
y = s1[[res]]
predictor = list(s1.columns)
x = s1[predictor]
x.head()
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y)
x_train.shape , y_train.shape , x_test.shape , y_train.shape
(x["drive"].value_counts(normalize = True) , x_test["drive"].value_counts(normalize = True))
# Out:
# (Rear-Wheel Drive     0.356797
#  Front-Wheel Drive    0.353552
#  All-Wheel Drive      0.239893
#  4-Wheel Drive        0.036480
#  2-Wheel Drive        0.013278
#  Name: drive, dtype: float64,
#  Rear-Wheel Drive     0.357599
#  Front-Wheel Drive    0.350027
#  All-Wheel Drive      0.238940
#  4-Wheel Drive        0.037642
#  2-Wheel Drive        0.015792
#  Name: drive, dtype: float64)
